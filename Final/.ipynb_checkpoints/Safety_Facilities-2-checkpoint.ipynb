# %% [markdown]
# ## Public Safety Structures Chart
# I found that the number of buildings dedicated for public safety reflect the care that a specific neighborhood has for it's residents. While the opinions from the residents of Pittsburgh can give useful information on safety, This chart directly represents the availabilty of safety resources in a community.

# %% [markdown]
# ## Importing and Loading Data

# %%
import pandas as pd
import matplotlib.pyplot as plt
pth = "fbb50b02-2879-47cd-abea-ae697ec05170.csv"
df = pd.read_csv(pth)

# %% [markdown]
# ## Locating and Sort Data

# %%
police = df[df["name"].str.contains("Police", case=False, na=False) |
             df["type"].str.contains("Police", case=False, na=False)]
fire = df[df["name"].str.contains("Fire", case=False, na=False) |
           df["type"].str.contains("Fire", case=False, na=False)]
medical_keywords = "Health|Medical|Clinic|Hospital|EMS|Ambulance|Rescue|Paramedic|Medic"
medical = df[df["name"].str.contains(medical_keywords, case=False, na=False) |
              df["type"].str.contains(medical_keywords, case=False, na=False)]

police_counts = police["neighborhood"].value_counts()
fire_counts = fire["neighborhood"].value_counts()
medical_counts = medical["neighborhood"].value_counts()

combined = pd.DataFrame({
    "Police Buildings": police_counts,
    "Firehouses": fire_counts,
    "Medical Buildings": medical_counts
}).fillna(0).astype(int)

combined["Total"] = combined.sum(axis=1)
combined = combined.sort_values("Total", ascending=False)

# %% [markdown]
# ## Chart of Data

# %%
print("\nNumber of Police, Fire, and Medical Buildings per Neighborhood:\n")
print(combined.sort_index())
# Out:
# Number of Police, Fire, and Medical Buildings per Neighborhood:
#
#                            Police Buildings  Firehouses  Medical Buildings  \
# neighborhood
# Allegheny West                            1           0                  0
# Allentown                                 1           0                  1
# Beechview                                 0           1                  0
# Bloomfield                                0           0                  1
# Bluff                                     1           1                  0
# Brighton Heights                          0           1                  0
# Brookline                                 0           1                  0
# California-Kirkbride                      1           0                  0
# Carrick                                   0           1                  0
# Central Business District                 2           0                  1
# Central Oakland                           0           1                  0
# Chateau                                   2           0                  0
# Crawford-Roberts                          1           0                  0
# East Allegheny                            0           1                  0
# East Liberty                              0           1                  0
# Elliott                                   0           1                  0
# Garfield                                  0           0                  1
# Greenfield                                0           1                  1
# Hays                                      0           1                  1
# Hazelwood                                 0           1                  0
# Highland Park                             2           1                  0
# Homewood South                            0           1                  0
# Homewood West                             0           0                  1
# Knoxville                                 0           0                  1
# Lincoln-Lemington-Belmar                  4           1                  0
# Lower Lawrenceville                       0           1                  0
# Manchester                                0           1                  0
# Marshall-Shadeland                        0           1                  1
# Middle Hill                               1           0                  0
# Mount Washington                          0           1                  0
# Perry North                               0           1                  0
# Perry South                               0           0                  1
# Shadyside                                 0           0                  1
# Sheraden                                  0           1                  0
# South Side Flats                          0           1                  0
# South Side Slopes                         0           1                  0
# Spring Hill-City View                     0           1                  0
# Squirrel Hill North                       1           1                  0
# Stanton Heights                           0           1                  0
# Strip District                            1           2                  1
# Swisshelm Park                            0           1                  0
# Troy Hill                                 1           0                  0
# West End                                  1           0                  1
# West Oakland                              0           1                  1
# Westwood                                  0           1                  0
#
#                            Total
# neighborhood
# Allegheny West                 1
# Allentown                      2
# Beechview                      1
# Bloomfield                     1
# Bluff                          2
# Brighton Heights               1
# Brookline                      1
# California-Kirkbride           1
# Carrick                        1
# Central Business District      3
# Central Oakland                1
# Chateau                        2
# Crawford-Roberts               1
# East Allegheny                 1
# East Liberty                   1
# Elliott                        1
# Garfield                       1
# Greenfield                     2
# Hays                           2
# Hazelwood                      1
# Highland Park                  3
# Homewood South                 1
# Homewood West                  1
# Knoxville                      1
# Lincoln-Lemington-Belmar       5
# Lower Lawrenceville            1
# Manchester                     1
# Marshall-Shadeland             2
# Middle Hill                    1
# Mount Washington               1
# Perry North                    1
# Perry South                    1
# Shadyside                      1
# Sheraden                       1
# South Side Flats               1
# South Side Slopes              1
# Spring Hill-City View          1
# Squirrel Hill North            2
# Stanton Heights                1
# Strip District                 4
# Swisshelm Park                 1
# Troy Hill                      1
# West End                       2
# West Oakland                   2
# Westwood                       1

# %% [markdown]
# ## Graph of Data

# %%
ax= combined[["Police Buildings", "Firehouses", "Medical Buildings"]].plot(
    kind="bar",
    stacked = True,
    figsize=(14, 7),
    width=.75,
    colormap = 'Set1'
)
plt.title("Number of Police, Fire, and Medical Buildings per Neighborhood")
plt.xlabel("Neighborhood")
plt.ylabel("Number of Buildings")
plt.xticks(rotation=75, ha="right")
plt.legend(title="Facility Type")
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
top_four = combined.head(4)
print("\nTop 4 Neighborhoods with the Most Safety-Related Buildings:\n")
print(top_four)
# Out:
# Top 4 Neighborhoods with the Most Safety-Related Buildings:
#
#                            Police Buildings  Firehouses  Medical Buildings  \
# neighborhood
# Lincoln-Lemington-Belmar                  4           1                  0
# Strip District                            1           2                  1
# Highland Park                             2           1                  0
# Central Business District                 2           0                  1
#
#                            Total
# neighborhood
# Lincoln-Lemington-Belmar       5
# Strip District                 4
# Highland Park                  3
# Central Business District      3

# %% [markdown]
# ## Conclusion
# Lincoln-Lemmington-Belmar, Strip District, Highland Park, and the Central Business District stand out for having the most infastructure dedicated to public safety. This shows the potential for protection and aid directly within a thier nieghborhood.
